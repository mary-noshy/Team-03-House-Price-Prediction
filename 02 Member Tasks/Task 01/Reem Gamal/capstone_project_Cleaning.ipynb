# %% [markdown]
# # Project 3: House Price Prediction
#
# Objective: Predict house prices based on various features like location, size, and house
# characteristics.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data
#
# We will open the .csv file to perform exploratory data analysis (EDA) to understand the dataset and
# visualize trends.

# %%
df = pd.read_csv("./data/house_prices.csv")

# %%
df.head()
# Out:
#    Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 0   1          60         RL         65.0     8450      Pave   NaN
# 1   2          20         RL         80.0     9600      Pave   NaN
# 2   3          60         RL         68.0    11250      Pave   NaN
# 3   4          70         RL         60.0     9550      Pave   NaN
# 4   5          60         RL         84.0    14260      Pave   NaN
#
#   Property_Shape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 0            Reg         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 1            Reg         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 2            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 3            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 4            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold YrSold  SaleType  SaleCondition  Property_Sale_Price
# 0       0      2   2008        WD         Normal               208500
# 1       0      5   2007        WD         Normal               181500
# 2       0      9   2008        WD         Normal               223500
# 3       0      2   2006        WD        Abnorml               140000
# 4       0     12   2008        WD         Normal               250000
#
# [5 rows x 81 columns]

# %% [markdown]
# ## Drop Columns

# %%
df = df.drop(['Id', 'PoolQC', 'MiscFeature', 'Alley', 'Fence'], axis=1)
#df.drop(['Id', 'PoolQC', 'MiscFeature', 'Alley', 'Fence', 'MasVnrType'], axis=1)

# %%
df.columns
# Out:
# Index(['Dwell_Type', 'Zone_Class', 'LotFrontage', 'LotArea', 'Road_Type',
#        'Property_Shape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'Dwelling_Type',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'Property_Sale_Price'],
#       dtype='object')

# %% [markdown]
# ## Fill NAN Values - Categorical Data

# %%
len(df)
# Out:
# 1460

# %%
df['MasVnrType'].fillna('NotExist', inplace=True)
df['FireplaceQu'].fillna('NotExist', inplace=True)
df['GarageFinish'].fillna('NotExist', inplace=True)
df['GarageQual'].fillna('NotExist', inplace=True)
df['GarageType'].fillna('NotExist', inplace=True)
df['GarageCond'].fillna('NotExist', inplace=True)
df['BsmtExposure'].fillna('NotExist', inplace=True)
df['BsmtFinType1'].fillna('NotExist', inplace=True)
df['BsmtFinType2'].fillna('NotExist', inplace=True)
df['BsmtQual'].fillna('NotExist', inplace=True)
df['BsmtCond'].fillna('NotExist', inplace=True)
# Out:
# /tmp/ipykernel_8496/851775140.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['MasVnrType'].fillna('NotExist', inplace=True)
# /tmp/ipykernel_8496/851775140.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['FireplaceQu'].fillna('NotExist', inplace=True)
# /tmp/ipykernel_8496/851775140.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['GarageFinish'].fillna('NotExist', inplace=True)
# /tmp/ipykernel_8496/851775140.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['GarageQual'].fillna('NotExist', inplace=True)
# /tmp/ipykernel_8496/851775140.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['GarageType'].fillna('NotExist', inplace=True)
# /tmp/ipykernel_8496/851775140.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['GarageCond'].fillna('NotExist', inplace=True)
# /tmp/ipykernel_8496/851775140.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['BsmtExposure'].fillna('NotExist', inplace=True)
# /tmp/ipykernel_8496/851775140.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['BsmtFinType1'].fillna('NotExist', inplace=True)
# /tmp/ipykernel_8496/851775140.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['BsmtFinType2'].fillna('NotExist', inplace=True)
# /tmp/ipykernel_8496/851775140.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['BsmtQual'].fillna('NotExist', inplace=True)
# /tmp/ipykernel_8496/851775140.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['BsmtCond'].fillna('NotExist', inplace=True)

# %%
df['Electrical'].unique()
print(df['Electrical'].isnull().sum())
#drop nan rows
df = df.dropna(subset=['Electrical'])
# Out:
# 1

# %% [markdown]
# ## Fill NAN Values - Numeric Data

# %%
df['GarageYrBlt'] = df['GarageYrBlt'].fillna(0)
# Out:
# /tmp/ipykernel_8496/1159045600.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['GarageYrBlt'] = df['GarageYrBlt'].fillna(0)

# %%
df['LotFrontage'] = df.groupby('Neighborhood')['LotFrontage'].transform(lambda val: val.fillna(val.mean()))
# Out:
# /tmp/ipykernel_8496/4276383293.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LotFrontage'] = df.groupby('Neighborhood')['LotFrontage'].transform(lambda val: val.fillna(val.mean()))

# %%
df["MasVnrArea"] = df["MasVnrArea"].fillna(0)
# Out:
# /tmp/ipykernel_8496/1615517271.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MasVnrArea"] = df["MasVnrArea"].fillna(0)

# %% [markdown]
# ## Use log Transform on Property_Sale_Price for better distribution

# %%
df['Property_Sale_Price_natural_log'] = np.log(df['Property_Sale_Price'])
# Out:
# /tmp/ipykernel_8496/2118678732.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Property_Sale_Price_natural_log'] = np.log(df['Property_Sale_Price'])

# %% [markdown]
# ## Dealing with Outliers

# %%
df[(df['SaleCondition'].isin(['Normal','Abnorml'])) & (df['Property_Sale_Price']>700000)]
# Out:
#       Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Property_Shape  \
# 691           60         RL        104.0    21535      Pave            IR1
# 1182          60         RL        160.0    15623      Pave            IR1
#
#      LandContour Utilities LotConfig LandSlope  ... 3SsnPorch ScreenPorch  \
# 691          Lvl    AllPub    Corner       Gtl  ...         0           0
# 1182         Lvl    AllPub    Corner       Gtl  ...         0           0
#
#      PoolArea MiscVal MoSold  YrSold  SaleType  SaleCondition  \
# 691         0       0      1    2007        WD         Normal
# 1182      555       0      7    2007        WD        Abnorml
#
#       Property_Sale_Price Property_Sale_Price_natural_log
# 691                755000                       13.534473
# 1182               745000                       13.521139
#
# [2 rows x 77 columns]

# %%
df[(df['GarageYrBlt']==0)]
# Out:
#       Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Property_Shape  \
# 39            90         RL    65.000000     6040      Pave            Reg
# 48           190         RM    33.000000     4456      Pave            Reg
# 78            90         RL    72.000000    10778      Pave            Reg
# 88            50    C (all)   105.000000     8470      Pave            IR1
# 89            20         RL    60.000000     8070      Pave            Reg
# ...          ...        ...          ...      ...       ...            ...
# 1349          70         RM    50.000000     5250      Pave            Reg
# 1407          20         RL    70.083333     8780      Pave            IR1
# 1449         180         RM    21.000000     1533      Pave            Reg
# 1450          90         RL    60.000000     9000      Pave            Reg
# 1453          20         RL    90.000000    17217      Pave            Reg
#
#      LandContour Utilities LotConfig LandSlope  ... 3SsnPorch ScreenPorch  \
# 39           Lvl    AllPub    Inside       Gtl  ...         0           0
# 48           Lvl    AllPub    Inside       Gtl  ...         0           0
# 78           Lvl    AllPub    Inside       Gtl  ...         0           0
# 88           Lvl    AllPub    Corner       Gtl  ...         0           0
# 89           Lvl    AllPub    Inside       Gtl  ...         0           0
# ...          ...       ...       ...       ...  ...       ...         ...
# 1349         Lvl    AllPub    Inside       Gtl  ...         0           0
# 1407         Lvl    AllPub    Corner       Gtl  ...         0           0
# 1449         Lvl    AllPub    Inside       Gtl  ...         0           0
# 1450         Lvl    AllPub       FR2       Gtl  ...         0           0
# 1453         Lvl    AllPub    Inside       Gtl  ...         0           0
#
#      PoolArea MiscVal MoSold  YrSold  SaleType  SaleCondition  \
# 39          0       0      6    2008        WD        AdjLand
# 48          0       0      6    2009       New        Partial
# 78          0       0      4    2010        WD         Normal
# 88          0       0     10    2009     ConLD        Abnorml
# 89          0       0      8    2007        WD         Normal
# ...       ...     ...    ...     ...       ...            ...
# 1349        0       0     12    2008        WD         Normal
# 1407        0       0      3    2009        WD         Normal
# 1449        0       0      8    2006        WD        Abnorml
# 1450        0       0      9    2009        WD         Normal
# 1453        0       0      7    2006        WD        Abnorml
#
#       Property_Sale_Price Property_Sale_Price_natural_log
# 39                  82000                       11.314475
# 48                 113000                       11.635143
# 78                 136500                       11.824080
# 88                  85000                       11.350407
# 89                 123600                       11.724806
# ...                   ...                             ...
# 1349               122000                       11.711776
# 1407               112000                       11.626254
# 1449                92000                       11.429544
# 1450               136000                       11.820410
# 1453                84500                       11.344507
#
# [81 rows x 77 columns]

# %% [markdown]
# ## Export Cleaned Data to CSV File

# %%
df.to_csv('cleaned_house_data.csv')

# %% [markdown]
# ----
